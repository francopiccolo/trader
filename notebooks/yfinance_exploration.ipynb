# %%
import yfinance as yf

# %% [markdown]
# # The Ticker module

# %%
msft = yf.Ticker('MSFT')

# %% [markdown]
# ## Period
# Valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
# ## Interval
# Valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
# Only 7 days worth of 1m granularity data are allowed to be fetched per request.
# The requested range must be within the last 730 days for 1h.
# The requested range must be within the last 60 days for 30m.

# %%
msft.history(period='60d', interval='30m')
# Out:
#                              Open    High     Low   Close   Volume  Dividends  \
# Datetime
# 2020-11-05 09:30:00-05:00  222.04  223.60  221.15  222.85  6869610        0.0
# 2020-11-05 10:00:00-05:00  222.84  224.00  222.19  222.34  3901152        0.0
# 2020-11-05 10:30:00-05:00  222.38  223.24  221.50  223.23  2607126        0.0
# 2020-11-05 11:00:00-05:00  223.22  223.34  222.16  222.73  1641653        0.0
# 2020-11-05 11:30:00-05:00  222.73  223.00  221.78  221.98  1593682        0.0
# 2020-11-05 12:00:00-05:00  221.99  222.95  221.72  221.85  1787740        0.0
# 2020-11-05 12:30:00-05:00  221.87  222.86  221.52  222.75  1207026        0.0
# 2020-11-05 13:00:00-05:00  222.77  223.23  222.69  222.95  1168732        0.0
# 2020-11-05 13:30:00-05:00  222.97  223.48  222.72  223.29  1336986        0.0
# 2020-11-05 14:00:00-05:00  223.31  223.79  223.16  223.76  1304425        0.0
# 2020-11-05 14:30:00-05:00  223.75  224.12  223.16  224.01  1930377        0.0
# ...

# %%
msft.info
# Out:
# {'zip': '98052',
#  'sector': 'Technology',
#  'fullTimeEmployees': 144000,
# ...

# %%
# get historical market data
hist = msft.history(period='max', interval='1min')

# %%
# show actions (dividends, splits)
msft.actions

# show dividends
msft.dividends

# show splits
msft.splits

# show financials
msft.financials
msft.quarterly_financials

# show major holders
msft.major_holders

# show institutional holders
msft.institutional_holders

# show balance heet
msft.balance_sheet
msft.quarterly_balance_sheet

# show cashflow
msft.cashflow
msft.quarterly_cashflow

# show earnings
msft.earnings
msft.quarterly_earnings

# show sustainability
msft.sustainability

# show analysts recommendations
msft.recommendations

# show next event (earnings, etc)
msft.calendar

# show ISIN code - *experimental*
# ISIN = International Securities Identification Number
msft.isin

# show options expirations
msft.options

# get option chain for specific expiration
opt = msft.option_chain('YYYY-MM-DD')
# data available via: opt.calls, opt.puts

# %%
msft.financials
# Out:
#                                          2019-06-30  2018-06-30  2017-06-30  \
# Research Development                     1.6876e+10  1.4726e+10  1.3037e+10
# Effect Of Accounting Charges                   None        None        None
# Income Before Tax                        4.3688e+10  3.6474e+10  2.9901e+10
# Minority Interest                              None        None        None
# Net Income                                3.924e+10  1.6571e+10  2.5489e+10
# Selling General Administrative           2.3098e+10  2.2223e+10  1.9942e+10
# Gross Profit                             8.2933e+10  7.2007e+10   6.231e+10
# Ebit                                     4.2959e+10  3.5058e+10  2.9331e+10
# Operating Income                         4.2959e+10  3.5058e+10  2.9331e+10
# Other Operating Expenses                       None        None        None
# Interest Expense                         -2.686e+09  -2.733e+09  -2.222e+09
# ...

# %%
msft.balance_sheet
# Out:
#                                     2019-06-30    2018-06-30    2017-06-30  \
# Intangible Assets                 7.750000e+09  8.053000e+09  1.010600e+10
# Total Liab                        1.842260e+11  1.761300e+11  1.626010e+11
# Total Stockholder Equity          1.023300e+11  8.271800e+10  8.771100e+10
# Other Current Liab                4.586000e+10  3.819500e+10  3.087900e+10
# Total Assets                      2.865560e+11  2.588480e+11  2.503120e+11
# Common Stock                      7.852000e+10  7.122300e+10  6.931500e+10
# Other Current Assets              1.013300e+10  6.855000e+09  5.183000e+09
# Retained Earnings                 2.415000e+10  1.368200e+10  1.776900e+10
# Other Liab                        3.569900e+10  3.570700e+10  2.298600e+10
# Good Will                         4.202600e+10  3.568300e+10  3.512200e+10
# Treasury Stock                   -3.400000e+08 -2.187000e+09  6.270000e+08
# ...

# %%
stocks = 'MSFT AAPL'
msft = yf.Ticker(stocks)

# %%
msft.info
# Out:
# ---------------------------------------------------------------------------
# InvalidURL                                Traceback (most recent call last)
# <ipython-input-26-c52d32a3ec1f> in <module>
# ----> 1 msft.info
#
# /opt/anaconda3/envs/stocks/lib/python3.8/site-packages/yfinance/ticker.py in info(self)
#     136     @property
#     137     def info(self):
# --> 138         return self.get_info()
#     139
#     140     @property
#
# /opt/anaconda3/envs/stocks/lib/python3.8/site-packages/yfinance/base.py in get_info(self, proxy, as_dict, *args, **kwargs)
#     415
#     416     def get_info(self, proxy=None, as_dict=False, *args, **kwargs):
# --> 417         self._get_fundamentals(proxy)
#     418         data = self._info
#     419         if as_dict:
#
# /opt/anaconda3/envs/stocks/lib/python3.8/site-packages/yfinance/base.py in _get_fundamentals(self, kind, proxy)
#     282         # holders
#     283         url = "{}/{}/holders".format(self._scrape_url, self.ticker)
# ...

# %% [markdown]
# # Fetching data for multiple tickers

# %%
import yfinance as yf
data = yf.download("SPY AAPL", start="2017-01-01", end="2017-04-30")

data = yf.download(  # or pdr.get_data_yahoo(...
        # tickers list or string as well
        tickers = "SPY AAPL MSFT",

        # use "period" instead of start/end
        # valid periods: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max
        # (optional, default is '1mo')
        period = "ytd",

        # fetch data by interval (including intraday if period < 60 days)
        # valid intervals: 1m,2m,5m,15m,30m,60m,90m,1h,1d,5d,1wk,1mo,3mo
        # (optional, default is '1d')
        interval = "1m",

        # group by ticker (to access via data['SPY'])
        # (optional, default is 'column')
        group_by = 'ticker',

        # adjust all OHLC automatically
        # (optional, default is False)
        auto_adjust = True,

        # download pre/post regular market hours data
        # (optional, default is False)
        prepost = True,

        # use threads for mass downloading? (True/False/Integer)
        # (optional, default is True)
        threads = True,

        # proxy URL scheme use use when downloading?
        # (optional, default is None)
        proxy = None
    )
